# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Admission_Prediction.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3        NaN        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.76
# 2           1             0.72
# 3           1             0.80
# 4           0             0.65
# ..        ...              ...
# 495         1             0.87
# 496         1             0.96
# 497         1             0.93
# 498         0             0.73
# 499         0             0.84
#
# [500 rows x 9 columns]

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  485.000000   490.000000         485.000000  500.000000
# mean   250.500000  316.558763   107.187755           3.121649    3.374000
# std    144.481833   11.274704     6.112899           1.146160    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR        CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# 25%      3.00000    8.127500    0.000000          0.63000
# 50%      3.50000    8.560000    1.000000          0.72000
# 75%      4.00000    9.040000    1.000000          0.82000
# max      5.00000    9.920000    1.000000          0.97000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          485 non-null    float64
#  2   TOEFL Score        490 non-null    float64
#  3   University Rating  485 non-null    float64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 35.3 KB

# %%
df.isnull().sum()
# Out:
# Serial No.            0
# GRE Score            15
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
df.isnull().sum().sort_values()
# Out:
# Serial No.            0
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# TOEFL Score          10
# GRE Score            15
# University Rating    15
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['GRE Score'] = df['GRE Score'].fillna(df['GRE Score'].mean())

# %%
df['TOEFL Score'] = df['TOEFL Score'].fillna(df['TOEFL Score'].mean())

# %%
df['University Rating'] = df['University Rating'].fillna(df['University Rating'].mean())

# %%
df
# Out:
#      Serial No.   GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1  337.000000        118.0                4.0  4.5  4.5  9.65
# 1             2  324.000000        107.0                4.0  4.0  4.5  8.87
# 2             3  316.558763        104.0                3.0  3.0  3.5  8.00
# 3             4  322.000000        110.0                3.0  3.5  2.5  8.67
# 4             5  314.000000        103.0                2.0  2.0  3.0  8.21
# ..          ...         ...          ...                ...  ...  ...   ...
# 495         496  332.000000        108.0                5.0  4.5  4.0  9.02
# 496         497  337.000000        117.0                5.0  5.0  5.0  9.87
# 497         498  330.000000        120.0                5.0  4.5  5.0  9.56
# 498         499  312.000000        103.0                4.0  4.0  5.0  8.43
# 499         500  327.000000        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.76
# 2           1             0.72
# 3           1             0.80
# 4           0             0.65
# ..        ...              ...
# 495         1             0.87
# 496         1             0.96
# 497         1             0.93
# 498         0             0.73
# 499         0             0.84
#
# [500 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
sns.pairplot(data =df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
X = df[['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
       'LOR', 'CGPA', 'Research']]

# %%
y = df['Chance of Admit']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.30)

# %%
X_train
# Out:
#      Serial No.   GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 190         191  324.000000        111.0                5.0  4.5  4.0  9.16
# 140         141  329.000000        110.0                2.0  4.0  3.0  9.15
# 15           16  314.000000        105.0                3.0  3.5  2.5  8.30
# 293         294  312.000000         98.0                1.0  3.5  3.0  8.18
# 254         255  321.000000        114.0                4.0  4.0  5.0  9.12
# ..          ...         ...          ...                ...  ...  ...   ...
# 351         352  325.000000        110.0                4.0  3.5  4.0  8.67
# 252         253  318.000000        100.0                2.0  2.5  3.5  8.54
# 126         127  323.000000        113.0                3.0  4.0  3.0  9.32
# 110         111  305.000000        108.0                5.0  3.0  3.0  8.48
# 218         219  316.558763        110.0                4.0  3.0  3.5  8.97
#
#      Research
# 190         1
# 140         1
# 15          0
# 293         1
# 254         0
# ..        ...
# 351         1
# 252         1
# 126         1
# 110         0
# 218         1
#
# [350 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
X_train =scalar.fit_transform(X_train)

# %%
X_test =scalar.transform(X_test)

# %%
X_train
# Out:
# array([[-0.41564164,  0.64164728,  0.57972164, ...,  0.51762166,
#          0.90877985,  0.88640526],
#        [-0.76000906,  1.08305741,  0.42101777, ..., -0.53567823,
#          0.89278744,  0.88640526],
#        [-1.62092762, -0.24117297, -0.37250158, ..., -1.06232818,
#         -0.466567  , -1.12815215],
#        ...,
#        [-0.85643194,  0.55336526,  0.89712937, ..., -0.53567823,
#          1.16465833,  0.88640526],
#        [-0.96662952, -1.0357112 ,  0.10361003, ..., -0.53567823,
#         -0.1787037 , -1.12815215],
#        [-0.22279588, -0.0152802 ,  0.42101777, ..., -0.00902828,
#          0.60492415,  0.88640526]])

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([0.81148132, 0.71732521, 0.67541034, 0.77255205, 0.62404126,
#        0.57443289, 0.60605136, 0.86070232, 0.71784355, 0.83698394,
#        0.62456021, 0.74643247, 0.85525639, 0.88204411, 0.94601611,
#        0.72006677, 0.94863056, 0.75288294, 0.65710676, 0.64218434,
#        0.82552139, 0.54656576, 0.6552603 , 0.5915099 , 0.76193843,
#        0.725336  , 0.66636304, 0.62588014, 0.52390112, 0.74689063,
#        0.68626802, 0.81639955, 0.70161227, 0.81789369, 0.68832933,
#        0.71411971, 0.48216121, 0.88692842, 0.51952602, 0.81980334,
#        0.70760371, 0.55440116, 0.78643337, 0.63959478, 0.63101771,
#        0.63903514, 0.77664757, 0.6456187 , 0.88001449, 0.51947514,
#        0.78334936, 0.68603721, 0.84098394, 0.94339169, 0.75104   ,
#        0.64796284, 0.7035211 , 0.7373233 , 0.62913188, 0.76251335,
#        0.63720145, 0.86142491, 0.63938943, 0.62254618, 0.78048556,
#        0.58787312, 0.67407115, 0.90405099, 0.84922257, 0.58943935,
#        0.64882193, 0.65153181, 0.8232801 , 0.81286157, 0.72458831,
#        0.68731003, 0.69003785, 0.95141719, 0.63259828, 0.64416882,
#        0.52422526, 0.67076318, 0.66932719, 0.72286767, 0.70064734,
#        0.93073744, 0.57209515, 0.73476285, 0.69985564, 0.60627723,
#        0.53488358, 0.70851666, 0.54079743, 0.66910531, 0.67806342,
#        0.52544456, 0.72834281, 0.94051602, 0.88269048, 0.94782562,
#        0.97956496, 0.85703869, 0.80330557, 0.84233611, 0.57225621,
#        0.61091301, 0.78377347, 0.79169226, 0.77944344, 0.64552322,
#        0.82619332, 0.57902408, 0.64521568, 0.66216077, 0.88684877,
#        0.61839522, 0.63938458, 0.7599258 , 0.49659233, 0.88978548,
#        0.72806425, 0.71648669, 0.71713104, 0.73575677, 0.86871259,
#        0.59204052, 0.61732208, 0.61304725, 0.65179852, 0.65979442,
#        0.74665662, 0.45941658, 0.70101594, 0.54668113, 0.76839319,
#        0.64156969, 0.74235614, 0.76566896, 0.70257697, 0.77665579,
#        0.8383177 , 0.66017465, 0.69343343, 1.00076648, 0.65989975,
#        0.66134117, 0.61109205, 0.63233187, 0.83978832, 0.67813409])

# %%
from sklearn.model_selection import cross_val_score

# %%
mse = cross_val_score(reg, X_train, y_train, cv =5)

# %%
np.mean(mse)
# Out:
# 0.8236301128821957

# %%
sns.displot(y_pred-y_test, kind ='kde')

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_pred , y_test)

# %%
score
# Out:
# 0.7429775985065651
